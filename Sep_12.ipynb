# %% [markdown]
# <a href="https://colab.research.google.com/github/Zach-Seymour/FDSFE_ZSeymour/blob/main/Sep_12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
movies = pd.read_csv('https://github.com/fedhere/FDSfE_FBianco/blob/main/data/'\
'movies_metadata_kaggle.csv.zip?raw=true',compression= 'zip')

# %%
movies.head()
# Out:
#    adult                              belongs_to_collection      budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000.0
# 1  False                                                NaN  65000000.0
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0.0
# 3  False                                                NaN  16000000.0
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0.0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# ...

# %%
movies.columns
# Out:
# Index(['adult', 'belongs_to_collection', 'budget', 'genres', 'homepage', 'id',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'video',
#        'vote_average', 'vote_count', 'earnings'],
#       dtype='object')

# %%
movies['popularity']
# Out:
# 0        21.946943
# 1        17.015539
# 2        11.712900
# 3         3.859495
# 4         8.387519
#            ...
# 45449     0.072051
# 45450     0.178241
# 45451     0.903007
# 45452     0.003503
# 45453     0.163015
# Name: popularity, Length: 45454, dtype: float64

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45454 entries, 0 to 45453
# Data columns (total 25 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  45454 non-null  bool
#  1   belongs_to_collection  4491 non-null   object
#  2   budget                 45454 non-null  float64
#  3   genres                 45454 non-null  object
#  4   homepage               7777 non-null   object
#  5   id                     45454 non-null  int64
#  6   imdb_id                45437 non-null  object
#  7   original_language      45443 non-null  object
#  8   original_title         45454 non-null  object
#  9   overview               44500 non-null  object
#  10  popularity             45451 non-null  float64
#  11  poster_path            45068 non-null  object
#  12  production_companies   45451 non-null  object
#  13  production_countries   45451 non-null  object
# ...

# %%
print(movies['runtime'])
# Out:
# 0         81.0
# 1        104.0
# 2        101.0
# 3        127.0
# 4        106.0
#          ...
# 45449     90.0
# 45450    360.0
# 45451     90.0
# 45452     87.0
# 45453     75.0
# Name: runtime, Length: 45454, dtype: object

# %%
for rt in movies['runtime'].values[630:640]:
  print(rt)
# Out:
# 108.0
# 107.0
# 90.0
# 97.0
# mean
# mean
# 106.0
# 117.0
# 110.0
# 85.0

# %%
mean_runtime =  pd.to_numeric(movies['runtime'], errors='coerce').mean()
pd.to_numeric(movies['runtime'],errors='coerce').fillna(mean_runtime).values[630:640]
# Out:
# array([108.        , 107.        ,  90.        ,  97.        ,
#         94.13309289,  94.13309289, 106.        , 117.        ,
#        110.        ,  85.        ])

# %%
pd.to_numeric(movies['runtime'],errors='coerce').dropna()
# Out:
# 0         81.0
# 1        104.0
# 2        101.0
# 3        127.0
# 4        106.0
#          ...
# 45449     90.0
# 45450    360.0
# 45451     90.0
# 45452     87.0
# 45453     75.0
# Name: runtime, Length: 45194, dtype: float64

# %%
movies['runtime'] = pd.to_numeric(movies['release_date']'])

# %%
import missingno as msno
msno.matrix(movies)
# Out:
# <Axes: >

# %%
msno.heatmap(movies)
# Out:
# <Axes: >

# %% [markdown]
# Drop columns(axis =1) or rows(axis =0) with only missing values(how=all), or any missing values(how='any')

# %%
movies.dropna(how='any', axis = 0)
# Out:
#        adult                              belongs_to_collection       budget  \
# 9      False  {'id': 645, 'name': 'James Bond Collection', '...   58000000.0
# 68     False  {'id': 43563, 'name': 'Friday Collection', 'po...    3500000.0
# 69     False  {'id': 10924, 'name': 'From Dusk Till Dawn Col...   19000000.0
# 153    False  {'id': 439053, 'name': 'Brooklyn Cigar Store C...    2000000.0
# 178    False  {'id': 286162, 'name': 'Power Rangers Collecti...   15000000.0
# ...      ...                                                ...          ...
# 43282  False  {'id': 87118, 'name': 'Cars Collection', 'post...  175000000.0
# 43997  False  {'id': 86066, 'name': 'Despicable Me Collectio...   80000000.0
# 44262  False  {'id': 173710, 'name': 'Planet of the Apes (Re...  152000000.0
# 44809  False  {'id': 34055, 'name': 'Pokémon Collection', 'p...   16000000.0
# 44830  False  {'id': 8650, 'name': 'Transformers Collection'...  260000000.0
#
# ...
